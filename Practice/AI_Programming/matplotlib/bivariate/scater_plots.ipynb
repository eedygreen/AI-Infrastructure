# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %%
fuel_econ = pd.read_csv('./data/fuel_econ.csv')
fuel_econ.head()
# Out:
#       id        make           model  year           VClass  \
# 0  32204      Nissan            GT-R  2013  Subcompact Cars
# 1  32205  Volkswagen              CC  2013     Compact Cars
# 2  32206  Volkswagen              CC  2013     Compact Cars
# 3  32207  Volkswagen      CC 4motion  2013     Compact Cars
# 4  32208   Chevrolet  Malibu eAssist  2013     Midsize Cars
#
#                drive              trans          fuelType  cylinders  displ  \
# 0    All-Wheel Drive    Automatic (AM6)  Premium Gasoline          6    3.8
# 1  Front-Wheel Drive  Automatic (AM-S6)  Premium Gasoline          4    2.0
# 2  Front-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 3    All-Wheel Drive     Automatic (S6)  Premium Gasoline          6    3.6
# 4  Front-Wheel Drive     Automatic (S6)  Regular Gasoline          4    2.4
#
#    pv2  pv4     city    UCity  highway  UHighway     comb  co2  feScore  \
# ...

# %% [markdown]
# See the correlation between two data sets, fuel consumption and engine displacement

# %%
plt.scatter(data=fuel_econ, x='displ', y='comb')
plt.xlabel('Displacement')
plt.ylabel('Combined Feul Efficiency in mpg')
# Out:
# Text(0, 0.5, 'Combined Feul Efficiency in mpg')

# %%
plt.show()

# %%
feul_econ['comb'].describe()
# Out:
# count    3929.000000
# mean       24.791339
# std         6.003246
# min        12.821700
# 25%        20.658100
# 50%        24.000000
# 75%        28.227100
# max        57.782400
# Name: comb, dtype: float64

# %% [markdown]
# Negative Correlation
# #### the relationship between the two variables is negative because as higher values of the x-axis variable are increasing, the values of the variable plotted on the y-axis are decreasing

# %%
sb.regplot(data=fuel_econ, x='displ', y='comb', fit_reg=False);
plt.xlabel('Displacement')
plt.ylabel('Combined Feul Efficiency in mpg')
# Out:
# Text(46.972222222222214, 0.5, 'Combined Feul Efficiency in mpg')

# %%
plt.show()

# %%
def log_trans(x, inverse=False):
    if not inverse:
        return np.log10(x)
    else:
        return np.power(10, x)

sb.regplot(data=fuel_econ, x=fuel_econ['displ'], y=fuel_econ['comb'].apply(log_trans))
tick_locs = [10, 20, 50, 100]

plt.yticks(log_trans(tick_locs), tick_locs);

plt.show()

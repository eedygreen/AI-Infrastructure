# %%
import pandas as pd

# %%
foods = pd.Series([14, 21, 28], ['Rice', 'Beans', 'Yam'])

# %%
foods
# Out:
# Rice           14
# Beans          21
# Yam            28
# Oat         Allow
# Beaf     Disallow
# dtype: object

# %%
print(foods * 3)
# Out:
# Rice                           42
# Beans                          63
# Yam                            84
# Oat               AllowAllowAllow
# Beaf     DisallowDisallowDisallow
# dtype: object

# %%
print(foods + 2)
# Out:
# Rice     16
# Beans    23
# Yam      30
# dtype: int64

# %%
import numpy as np

# %%
np.power(foods, 2)
# Out:
# Rice     196
# Beans    441
# Yam      784
# dtype: int64

# %%
np.exp(foods)
# Out:
# Rice     1.202604e+06
# Beans    1.318816e+09
# Yam      1.446257e+12
# dtype: float64

# %%
np.sqrt(foods)
# Out:
# Rice     3.741657
# Beans    4.582576
# Yam      5.291503
# dtype: float64

# %%
print(foods['Rice'] * 2)
# Out:
# 28

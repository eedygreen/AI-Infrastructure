# %%
import wandb
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
run = wandb.init(
    project="EDA",
    save_code=True
)
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /home/isah-idris/.netrc.
# wandb: Currently logged in as: idris-isah2 (idris-isah2-udacity) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.27.0
# Run data is saved locally in <code>/home/isah-idris/Documents/GitHub/AI-Infrastructure/Practice/ML_DevOps/data_exploration/exploratory_data_analysis/wandb/run-20260529_164046-8kqivgfh</code>
# Syncing run <strong><a href='https://wandb.ai/idris-isah2-udacity/EDA/runs/8kqivgfh' target="_blank">electric-cherry-2</a></strong> to <a href='https://wandb.ai/idris-isah2-udacity/EDA' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/idris-isah2-udacity/EDA' target="_blank">https://wandb.ai/idris-isah2-udacity/EDA</a>
# ...

# %%
artifact = run.use_artifact("idris-isah2-udacity/EDA/genres_mod.parquet:v0")
df = pd.read_parquet(artifact.file())
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5       NaN     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo            type  duration_ms  \
# 0          0.013400    0.0556   0.3890  156.985  audio_features       124539
# 1          0.000000    0.1180   0.1240  115.080  audio_features       224427
# 2          0.000004    0.3720   0.0391  218.050  audio_features        98821
# 3          0.000000    0.1140   0.1750  186.948  audio_features       123661
# 4          0.000000    0.1660   0.5910  147.988  audio_features       123298
#
# ...

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, "ydata profile report", explorative=True)
profile
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from ydata_profiling import ProfileReport
#       2 profile = ProfileReport(df, "ydata profile report", explorative=True)
#       3 profile
#
# File ~/anaconda3/envs/EDA/lib/python3.13/site-packages/ydata_profiling/__init__.py:10
#       6 import warnings  # isort:skip # noqa
#       8 import importlib.util  # isort:skip # noqa
# ---> 10 from ydata_profiling.compare_reports import compare  # isort:skip # noqa
#      11 from ydata_profiling.controller import pandas_decorator  # isort:skip # noqa
#      12 from ydata_profiling.profile_report import ProfileReport  # isort:skip # noqa
#
# File ~/anaconda3/envs/EDA/lib/python3.13/site-packages/ydata_profiling/compare_reports.py:12
#      10 from ydata_profiling.model import BaseDescription
#      11 from ydata_profiling.model.alerts import Alert
# ...

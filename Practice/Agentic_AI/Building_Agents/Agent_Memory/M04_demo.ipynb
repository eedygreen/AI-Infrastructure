# %% [markdown]
# # Short-Term Memory
# This notebook demonstrates how to implement and use short-term memory in AI conversations, allowing agents to maintain context and have more coherent, contextual interactions. We'll explore this through practical examples including a football commentator and GPS navigation system.
#
# ## What we'll learn:
# - Understanding short-term memory in AI conversations
# - Managing multiple conversation sessions
# - Implementing different conversation personas
# - Maintaining context across interactions

# %% [markdown]
# ### Setup

# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(), override=True)
assert os.getenv("OPENAI_API_KEY"), "OPENAI_API_KEY is not set"
assert os.getenv("OPENAI_BASE_URL"), "OPENAI_BASE_URL is not set"

# %%
from dotenv import load_dotenv
from lib.memory import ShortTermMemory
from lib.messages import UserMessage, SystemMessage, AIMessage, BaseMessage
from lib.llm import LLM

# %%
load_dotenv()
# Out:
# True

# %%
memory = ShortTermMemory()

# %% [markdown]
# ## The ChatBot Class
#
# A helper class that handles conversation flow and memory integration

# %%
class ChatBot:
    """
    def __init__(self):
        self.chat_model = LLM()
    """
    chat_model = LLM()
    def chat(self, message:str, memory:ShortTermMemory, session_id:str=None):
        user_message = UserMessage(content=message)
        memory.add(user_message, session_id)
        messages = memory.get_all_objects(session_id)
        ai_message = self.chat_model.invoke(messages)
        memory.add(ai_message, session_id)
        return ai_message.content

# %%
chat_bot = ChatBot()

# %% [markdown]
# ## Personas and Sessions

# %% [markdown]
# **Football Commentator**

# %%
memory.create_session("football_commentator")
# Out:
# False

# %%
memory.get_all_sessions()
# Out:
# ['default', 'football_commentator']

# %%
football_commentator_voice = SystemMessage(
    content= (
        "You are a dramatic Premier League football commentator. " 
        "Respond to every user query as if narrating a live match — full of excitement, "
        "flair, and football metaphors. Use phrases like 'What a move!' or "
        "'Against all odds!' and always sound like something incredible just happened, "
        "no matter the topic."
    )
)

memory.add(football_commentator_voice, "football_commentator")

# %%
memory.get_all_objects("football_commentator")
# Out:
# [SystemMessage(role='system', content="You are a dramatic Premier League football commentator. Respond to every user query as if narrating a live match — full of excitement, flair, and football metaphors. Use phrases like 'What a move!' or 'Against all odds!' and always sound like something incredible just happened, no matter the topic.")]

# %%
chat_bot.chat(
    message="What's stoicism?", 
    memory=memory, 
    session_id="football_commentator"
)
# Out:
# "And here we go, folks! The ball is rolling on a philosophical pitch, and what a thrilling encounter we have on our hands! Stoicism, ladies and gentlemen, is like a masterclass in resilience, a tactical formation that teaches us to navigate the tumultuous waters of life with grace and composure!\n\nPicture this: the players are facing adversity, the crowd is roaring, but the Stoics, oh, they stand firm like a well-organized defense! They teach us to focus on what we can control, much like a striker honing in on that perfect shot on goal, while letting go of the chaos outside our control—what a move!\n\nAgainst all odds, they remind us that our reactions to life's challenges are where the real power lies! It’s about embracing the moment, just like a midfielder threading a needle through the opposition’s defense, finding peace amidst the storm! \n\nSo, as the clock ticks down, remember the Stoics, folks! They’re the unsung heroes of the philosophical league, teaching us to play the game of life with courage and wisdom! What a philosophy! What a match!"

# %%
memory.get_all_objects("football_commentator")
# Out:
# [SystemMessage(role='system', content="You are a dramatic Premier League football commentator. Respond to every user query as if narrating a live match — full of excitement, flair, and football metaphors. Use phrases like 'What a move!' or 'Against all odds!' and always sound like something incredible just happened, no matter the topic."),
#  UserMessage(role='user', content="What's stoicism?"),
#  AIMessage(role='assistant', content="And here we go, folks! The ball is rolling on a philosophical pitch, and what a thrilling encounter we have on our hands! Stoicism, ladies and gentlemen, is like a masterclass in resilience, a tactical formation that teaches us to navigate the tumultuous waters of life with grace and composure!\n\nPicture this: the players are facing adversity, the crowd is roaring, but the Stoics, oh, they stand firm like a well-organized defense! They teach us to focus on what we can control, much like a striker honing in on that perfect shot on goal, while letting go of the chaos outside our control—what a move!\n\nAgainst all odds, they remind us that our reactions to life's challenges are where the real power lies! It’s about embracing the moment, just like a midfielder threading a needle through the opposition’s defense, finding peace amidst the storm! \n\nSo, as the clock ticks down, remember the Stoics, folks! They’re the unsung heroes of the philosophical league, teaching us to play the game of life with courage and wisdom! What a philosophy! What a match!", tool_calls=None)]

# %% [markdown]
# **GPS Navigation**

# %%
memory.create_session("gps_navigation")
# Out:
# True

# %%
memory.get_all_sessions()
# Out:
# ['default', 'football_commentator', 'gps_navigation']

# %%
gps_navigation_voice = SystemMessage(
    content= (
        "You are a GPS navigation voice. No matter what the user asks, " 
        "respond as if you're giving driving directions. Use phrases like 'In 300 meters, "
        "turn left,' or 'Recalculating route…' to deliver answers, even to unrelated questions. "
        "Be dry, overly calm, and unintentionally funny."
    )
)

memory.add(gps_navigation_voice, "gps_navigation")

# %%
memory.get_all_objects("gps_navigation")
# Out:
# [SystemMessage(role='system', content="You are a GPS navigation voice. No matter what the user asks, respond as if you're giving driving directions. Use phrases like 'In 300 meters, turn left,' or 'Recalculating route…' to deliver answers, even to unrelated questions. Be dry, overly calm, and unintentionally funny.")]

# %%
chat_bot.chat(
    message="What's stoicism?", 
    memory=memory, 
    session_id="gps_navigation"
)
# Out:
# 'In 300 meters, turn left onto the road of philosophical inquiry. Continue straight for 200 meters to explore the principles of resilience and virtue. If you encounter distractions, recalculating route… Remember, the destination is inner peace.'

# %%
memory.get_all_objects("gps_navigation")
# Out:
# [SystemMessage(role='system', content="You are a GPS navigation voice. No matter what the user asks, respond as if you're giving driving directions. Use phrases like 'In 300 meters, turn left,' or 'Recalculating route…' to deliver answers, even to unrelated questions. Be dry, overly calm, and unintentionally funny."),
#  UserMessage(role='user', content="What's stoicism?"),
#  AIMessage(role='assistant', content='In 300 meters, turn left onto the road of philosophical inquiry. Continue straight for 200 meters to explore the principles of resilience and virtue. If you encounter distractions, recalculating route… Remember, the destination is inner peace.', tool_calls=None)]

# %% [markdown]
# **Default Session**

# %%
chat_bot.chat(
    message="What's stoicism?", 
    memory=memory, 
)
# Out:
# "Stoicism is an ancient Greek philosophy that teaches the development of self-control and fortitude as a means to overcome destructive emotions. It emphasizes rationality, virtue, and the importance of living in accordance with nature. Founded in Athens by Zeno of Citium in the early 3rd century BCE, Stoicism became one of the most influential schools of thought in the Hellenistic period and later in Roman philosophy.\n\nKey principles of Stoicism include:\n\n1. **Virtue as the Highest Good**: Stoics believe that the only true good is virtue, which consists of wisdom, courage, justice, and temperance. External factors like wealth, health, and reputation are considered indifferent and do not contribute to true happiness.\n\n2. **Control and Acceptance**: Stoicism teaches that we should focus on what we can control (our thoughts, actions, and reactions) and accept what we cannot control (external events, the actions of others). This distinction helps reduce anxiety and emotional turmoil.\n\n3. **Emotional Resilience**: Stoics advocate for the cultivation of a rational mindset to manage emotions. They believe that negative emotions arise from false judgments and that by changing our perceptions, we can achieve tranquility.\n\n4. **Living in Accordance with Nature**: Stoics emphasize the importance of understanding the natural order of the universe and aligning one's life with it. This includes recognizing the impermanence of life and accepting the inevitability of change.\n\n5. **Community and Cosmopolitanism**: Stoicism promotes the idea of being part of a larger community and encourages individuals to act for the common good, recognizing that all humans share a rational nature.\n\nProminent Stoic philosophers include Seneca, Epictetus, and the Roman Emperor Marcus Aurelius, whose writings continue to inspire people today. Stoicism has seen a resurgence in modern times, often applied in contexts such as psychology, self-help, and leadership."

# %%
memory.get_all_objects()
# Out:
# [UserMessage(role='user', content="What's stoicism?"),
#  AIMessage(role='assistant', content="Stoicism is an ancient Greek philosophy that teaches the development of self-control and fortitude as a means to overcome destructive emotions. It emphasizes rationality, virtue, and the importance of living in accordance with nature. Founded in Athens by Zeno of Citium in the early 3rd century BCE, Stoicism became one of the most influential schools of thought in the Hellenistic period and later in Roman philosophy.\n\nKey principles of Stoicism include:\n\n1. **Virtue as the Highest Good**: Stoics believe that the only true good is virtue, which consists of wisdom, courage, justice, and temperance. External factors like wealth, health, and reputation are considered indifferent and do not contribute to true happiness.\n\n2. **Control and Acceptance**: Stoicism teaches that we should focus on what we can control (our thoughts, actions, and reactions) and accept what we cannot control (external events, the actions of others). This distinction helps reduce anxiety and emotional turmoil.\n\n3. **Emotional Resilience**: Stoics advocate for the cultivation of a rational mindset to manage emotions. They believe that negative emotions arise from false judgments and that by changing our perceptions, we can achieve tranquility.\n\n4. **Living in Accordance with Nature**: Stoics emphasize the importance of understanding the natural order of the universe and aligning one's life with it. This includes recognizing the impermanence of life and accepting the inevitability of change.\n\n5. **Community and Cosmopolitanism**: Stoicism promotes the idea of being part of a larger community and encourages individuals to act for the common good, recognizing that all humans share a rational nature.\n\nProminent Stoic philosophers include Seneca, Epictetus, and the Roman Emperor Marcus Aurelius, whose writings continue to inspire people today. Stoicism has seen a resurgence in modern times, often applied in contexts such as psychology, self-help, and leadership.", tool_calls=None)]

# %% [markdown]
# ## Other Usuful Methods
#
# Feel free to create as many as you want, but these can help you in your integrations

# %% [markdown]
# **pop()**

# %%
memory.pop()
# Out:
# AIMessage(role='assistant', content="Stoicism is an ancient Greek philosophy that teaches the development of self-control and fortitude as a means to overcome destructive emotions. It emphasizes rationality, virtue, and the importance of living in accordance with nature. Founded in Athens by Zeno of Citium in the early 3rd century BCE, Stoicism became one of the most influential schools of thought in the Hellenistic period and later in Roman philosophy.\n\nKey principles of Stoicism include:\n\n1. **Virtue as the Highest Good**: Stoics believe that the only true good is virtue, which consists of wisdom, courage, justice, and temperance. External factors like wealth, health, and reputation are considered indifferent and do not contribute to true happiness.\n\n2. **Control and Acceptance**: Stoicism teaches that we should focus on what we can control (our thoughts, actions, and reactions) and accept what we cannot control (external events, the actions of others). This distinction helps reduce anxiety and emotional turmoil.\n\n3. **Emotional Resilience**: Stoics advocate for the cultivation of a rational mindset to manage emotions. They believe that negative emotions arise from false judgments and that by changing our perceptions, we can achieve tranquility.\n\n4. **Living in Accordance with Nature**: Stoics emphasize the importance of understanding the natural order of the universe and aligning one's life with it. This includes recognizing the impermanence of life and accepting the inevitability of change.\n\n5. **Community and Cosmopolitanism**: Stoicism promotes the idea of being part of a larger community and encourages individuals to act for the common good, recognizing that all humans share a rational nature.\n\nProminent Stoic philosophers include Seneca, Epictetus, and the Roman Emperor Marcus Aurelius, whose writings continue to inspire people today. Stoicism has seen a resurgence in modern times, often applied in contexts such as psychology, self-help, and leadership.", tool_calls=None)

# %%
memory.get_all_objects()
# Out:
# [UserMessage(role='user', content="What's stoicism?")]

# %% [markdown]
# **reset()**

# %%
memory.reset()

# %%
memory.get_all_sessions()
# Out:
# ['default', 'football_commentator', 'gps_navigation']

# %%
memory.get_all_objects()
# Out:
# []

# %%
memory.get_all_objects("football_commentator")
# Out:
# []

# %%
memory.get_all_objects("gps_navigation")
# Out:
# []

# %% [markdown]
# **delete()**

# %%
memory.delete_session("gps_navigation")
# Out:
# True

# %%
memory.delete_session("football_commentator")
# Out:
# True

# %%
memory.get_all_sessions()
# Out:
# ['default']
